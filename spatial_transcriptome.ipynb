# %% [markdown]
# # Gouin et al.
#
# 空間トランスクリプトーム
#
# Gouin, K.H., Ing, N., Plummer, J.T. et al. An N-Cadherin 2 expressing epithelial cell subpopulation predicts response to surgery, chemotherapy and immunotherapy in bladder cancer. Nat Commun 12, 4906 (2021). https://doi.org/10.1038/s41467-021-25103-7

# %%
import os
import sys
import gzip
import numpy as np
import pandas as pd
pd.options.display.max_columns = None

import scanpy as sc
import anndata
import squidpy as sq

# %% [markdown]
# ## Data download

# %%
# !mkdir -p Gouin-2021-Nat_Commun-Bladder_cancer/single_cell
# !mkdir -p Gouin-2021-Nat_Commun-Bladder_cancer/spatial

# %% [markdown]
# ### snRNA-seq
#
# Single-nuclei RNA-seq data is reposited in Gene Expression Omnibus with accession number [GSE169379](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE169379)

# %% [markdown]
# #### Metadata

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/matrix/GSE169379_series_matrix.txt.gz -O Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_series_matrix.txt.gz
# Out:
# --2021-12-26 18:51:06--  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/matrix/GSE169379_series_matrix.txt.gz
#            => 'Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_series_matrix.txt.gz'
# Resolving ftp.ncbi.nlm.nih.gov... 130.14.250.7, 165.112.9.229
# Connecting to ftp.ncbi.nlm.nih.gov|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /geo/series/GSE169nnn/GSE169379/matrix ... done.
# ==> SIZE GSE169379_series_matrix.txt.gz ... 6404
# ==> PASV ... done.    ==> RETR GSE169379_series_matrix.txt.gz ... done.
# Length: 6404 (6.3K) (unauthoritative)
#
# 100%[======================================>] 6,404       --.-K/s   in 0.04s
#
# 2021-12-26 18:51:08 (179 KB/s) - 'Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_series_matrix.txt.gz' saved [6404]

# %%
n_sample = 30
with gzip.open("Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_series_matrix.txt.gz", "rt") as fi:
    meta = []
    for i,j in enumerate(fi):
        dat = j.strip('\n!').split("\t")
        if len(dat) != n_sample + 1: continue
        dat = [d.strip('"') for d in dat]
        meta.append(dat)
meta = pd.DataFrame(meta).set_index(0).T.set_index("ID_REF").iloc[:,[0, 8, 9]]
meta.columns = ["sample_title", "organism", "tissue"]
meta = meta.assign(sample_id = lambda x: [y.split(": ")[0] for y in x.sample_title],
                   donor_id = lambda x: [y.split(": ")[1] for y in x.sample_title],
                   tissue = lambda x: [y.split(": ")[1] for y in x.tissue])
meta
# Out:
#                        sample_title      organism  \
# ID_REF
# GSM5199001  B1246-GEX: MIBC_rxn1246  Homo sapiens
# GSM5199003  B1246-HTO: MIBC_rxn1246  Homo sapiens
# GSM5199004        B1-GEX: MIBC_rxn1  Homo sapiens
# GSM5199005        B1-HTO: MIBC_rxn1  Homo sapiens
# GSM5199006        B2-GEX: MIBC_rxn2  Homo sapiens
# GSM5199007        B2-HTO: MIBC_rxn2  Homo sapiens
# GSM5199008        B3-GEX: MIBC_rxn3  Homo sapiens
# GSM5199009        B3-HTO: MIBC_rxn3  Homo sapiens
# GSM5199011        B4-GEX: MIBC_rxn4  Homo sapiens
# GSM5199012        B4-HTO: MIBC_rxn4  Homo sapiens
# GSM5199013      B5A-GEX: MIBC_rxn5A  Homo sapiens
# GSM5199014      B5A-HTO: MIBC_rxn5A  Homo sapiens
# GSM5199015      B5B-GEX: MIBC_rxn5B  Homo sapiens
# GSM5199016      B5B-HTO: MIBC_rxn5B  Homo sapiens
# GSM5199017      B6A-GEX: MIBC_rxn6A  Homo sapiens
# GSM5199019      B6A-HTO: MIBC_rxn6A  Homo sapiens
# GSM5199020      B6B-GEX: MIBC_rxn6B  Homo sapiens
# GSM5199021      B6B-HTO: MIBC_rxn6B  Homo sapiens
# GSM5199022      B7A-GEX: MIBC_rxn7A  Homo sapiens
# GSM5199023      B7A-HTO: MIBC_rxn7A  Homo sapiens
# GSM5199025      B7B-GEX: MIBC_rxn7B  Homo sapiens
# GSM5199026      B7B-HTO: MIBC_rxn7B  Homo sapiens
# GSM5199027      B8A-GEX: MIBC_rxn8A  Homo sapiens
# GSM5199028      B8A-HTO: MIBC_rxn8A  Homo sapiens
# GSM5199029      B8B-GEX: MIBC_rxn8B  Homo sapiens
# GSM5199030      B8B-HTO: MIBC_rxn8B  Homo sapiens
# GSM5199031  normalA: normal_sampleA  Homo sapiens
# GSM5199033  normalB: normal_sampleB  Homo sapiens
# GSM5199034  normalC: normal_sampleC  Homo sapiens
# GSM5199035  normalD: normal_sampleD  Homo sapiens
#
#                                            tissue  sample_id        donor_id
# ID_REF
# GSM5199001  muscle-invasive bladder cancer (MIBC)  B1246-GEX    MIBC_rxn1246
# GSM5199003  muscle-invasive bladder cancer (MIBC)  B1246-HTO    MIBC_rxn1246
# GSM5199004  muscle-invasive bladder cancer (MIBC)     B1-GEX       MIBC_rxn1
# GSM5199005  muscle-invasive bladder cancer (MIBC)     B1-HTO       MIBC_rxn1
# GSM5199006  muscle-invasive bladder cancer (MIBC)     B2-GEX       MIBC_rxn2
# GSM5199007  muscle-invasive bladder cancer (MIBC)     B2-HTO       MIBC_rxn2
# GSM5199008  muscle-invasive bladder cancer (MIBC)     B3-GEX       MIBC_rxn3
# GSM5199009  muscle-invasive bladder cancer (MIBC)     B3-HTO       MIBC_rxn3
# GSM5199011  muscle-invasive bladder cancer (MIBC)     B4-GEX       MIBC_rxn4
# GSM5199012  muscle-invasive bladder cancer (MIBC)     B4-HTO       MIBC_rxn4
# GSM5199013  muscle-invasive bladder cancer (MIBC)    B5A-GEX      MIBC_rxn5A
# GSM5199014  muscle-invasive bladder cancer (MIBC)    B5A-HTO      MIBC_rxn5A
# GSM5199015  muscle-invasive bladder cancer (MIBC)    B5B-GEX      MIBC_rxn5B
# GSM5199016  muscle-invasive bladder cancer (MIBC)    B5B-HTO      MIBC_rxn5B
# GSM5199017  muscle-invasive bladder cancer (MIBC)    B6A-GEX      MIBC_rxn6A
# GSM5199019  muscle-invasive bladder cancer (MIBC)    B6A-HTO      MIBC_rxn6A
# GSM5199020  muscle-invasive bladder cancer (MIBC)    B6B-GEX      MIBC_rxn6B
# GSM5199021  muscle-invasive bladder cancer (MIBC)    B6B-HTO      MIBC_rxn6B
# GSM5199022  muscle-invasive bladder cancer (MIBC)    B7A-GEX      MIBC_rxn7A
# GSM5199023  muscle-invasive bladder cancer (MIBC)    B7A-HTO      MIBC_rxn7A
# GSM5199025  muscle-invasive bladder cancer (MIBC)    B7B-GEX      MIBC_rxn7B
# GSM5199026  muscle-invasive bladder cancer (MIBC)    B7B-HTO      MIBC_rxn7B
# GSM5199027  muscle-invasive bladder cancer (MIBC)    B8A-GEX      MIBC_rxn8A
# GSM5199028  muscle-invasive bladder cancer (MIBC)    B8A-HTO      MIBC_rxn8A
# GSM5199029  muscle-invasive bladder cancer (MIBC)    B8B-GEX      MIBC_rxn8B
# GSM5199030  muscle-invasive bladder cancer (MIBC)    B8B-HTO      MIBC_rxn8B
# GSM5199031                         normal bladder    normalA  normal_sampleA
# GSM5199033                         normal bladder    normalB  normal_sampleB
# GSM5199034                         normal bladder    normalC  normal_sampleC
# GSM5199035                         normal bladder    normalD  normal_sampleD

# %% [markdown]
# #### Expression

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/suppl/GSE169379_MIBC_snSeq.h5ad.gz -O Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_MIBC_snSeq.h5ad.gz
# !gunzip Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_MIBC_snSeq.h5ad.gz
# Out:
# --2021-12-26 18:59:04--  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/suppl/GSE169379_MIBC_snSeq.h5ad.gz
#            => 'GSE169379_MIBC_snSeq.h5ad.gz'
# Resolving ftp.ncbi.nlm.nih.gov... 130.14.250.13, 165.112.9.229
# Connecting to ftp.ncbi.nlm.nih.gov|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /geo/series/GSE169nnn/GSE169379/suppl ... done.
# ==> SIZE GSE169379_MIBC_snSeq.h5ad.gz ... 473158739
# ==> PASV ... done.    ==> RETR GSE169379_MIBC_snSeq.h5ad.gz ... done.
# Length: 473158739 (451M) (unauthoritative)
#
# 100%[======================================>] 473,158,739 5.99MB/s   in 85s
#
# 2021-12-26 19:00:31 (5.33 MB/s) - 'GSE169379_MIBC_snSeq.h5ad.gz' saved [473158739]

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/suppl/GSE169379_non_tumor_snSeq.h5ad.gz -O Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_non_tumor_snSeq.h5ad.gz
# !gunzip Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_non_tumor_snSeq.h5ad.gz
# Out:
# --2021-12-26 19:16:36--  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE169nnn/GSE169379/suppl/GSE169379_non_tumor_snSeq.h5ad.gz
#            => 'Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_non_tumor_snSeq.h5ad.gz'
# Resolving ftp.ncbi.nlm.nih.gov... 130.14.250.13, 165.112.9.229
# Connecting to ftp.ncbi.nlm.nih.gov|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /geo/series/GSE169nnn/GSE169379/suppl ... done.
# ==> SIZE GSE169379_non_tumor_snSeq.h5ad.gz ... 87784694
# ==> PASV ... done.    ==> RETR GSE169379_non_tumor_snSeq.h5ad.gz ... done.
# Length: 87784694 (84M) (unauthoritative)
#
# 100%[======================================>] 87,784,694  4.35MB/s   in 18s
#
# 2021-12-26 19:16:56 (4.66 MB/s) - 'Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_non_tumor_snSeq.h5ad.gz' saved [87784694]

# %%
adata = sc.read_h5ad("Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_MIBC_snSeq.h5ad")
adata

# %%
adata = sc.read_h5ad("Gouin-2021-Nat_Commun-Bladder_cancer/single_cell/GSE169379_non_tumor_snSeq.h5ad")
adata

# %% [markdown]
# ### Spatial transcriptomics
#
# Spatial transcriptome data is reposited in Gene Expression Omnibus with accession number [GSE171351](https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE171351)

# %%
# !wget ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE171nnn/GSE171351/suppl/GSE171351_combined_visium.h5ad.gz -O Gouin-2021-Nat_Commun-Bladder_cancer/spatial/GSE171351_combined_visium.h5ad.gz
# !gunzip Gouin-2021-Nat_Commun-Bladder_cancer/spatial/GSE171351_combined_visium.h5ad.gz
# Out:
# --2021-12-26 19:23:01--  ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE171nnn/GSE171351/suppl/GSE171351_combined_visium.h5ad.gz
#            => 'Gouin-2021-Nat_Commun-Bladder_cancer/spatial/GSE171351_combined_visium.h5ad.gz'
# Resolving ftp.ncbi.nlm.nih.gov... 165.112.9.229, 130.14.250.13
# Connecting to ftp.ncbi.nlm.nih.gov|165.112.9.229|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /geo/series/GSE171nnn/GSE171351/suppl ... done.
# ==> SIZE GSE171351_combined_visium.h5ad.gz ... 48963566
# ==> PASV ... done.    ==> RETR GSE171351_combined_visium.h5ad.gz ... done.
# Length: 48963566 (47M) (unauthoritative)
#
# 100%[======================================>] 48,963,566  6.24MB/s   in 9.5s
#
# 2021-12-26 19:23:13 (4.92 MB/s) - 'Gouin-2021-Nat_Commun-Bladder_cancer/spatial/GSE171351_combined_visium.h5ad.gz' saved [48963566]

# %% [markdown]
# ## Analysis

# %%
adata = sc.read_h5ad("Gouin-2021-Nat_Commun-Bladder_cancer/spatial/GSE171351_combined_visium.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 4086 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'sampleID', 'Patient', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'n_counts'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
adata.obs
# Out:
#                           in_tissue  array_row  array_col sampleID  \
# AAACCGTTCGTCCAGG-1-0-0-0          1         52         42       A1
# AAACGAGACGGTTGAT-1-0-0-0          1         35         79       A1
# AAACTGCTGGCTCCAA-1-0-0-0          1         45         67       A1
# AAAGGCTACGGACCAT-1-0-0-0          1         62         54       A1
# AAAGGCTCTCGCGCCG-1-0-0-0          1         55         55       A1
# ...                             ...        ...        ...      ...
# TTGTGCAGCCACGTCA-1-1              1         60         74       D1
# TTGTGGCCCTGACAGT-1-1              1         18         60       D1
# TTGTGTTTCCCGAAAG-1-1              1         51         59       D1
# TTGTTAGCAAATTCGA-1-1              1         22         42       D1
# TTGTTCAGTGTGCTAC-1-1              1         24         64       D1
#
#                               Patient  n_genes_by_counts  \
# AAACCGTTCGTCCAGG-1-0-0-0  Bladder1204               1221
# AAACGAGACGGTTGAT-1-0-0-0  Bladder1204               3257
# AAACTGCTGGCTCCAA-1-0-0-0  Bladder1204               3385
# AAAGGCTACGGACCAT-1-0-0-0  Bladder1204               2392
# AAAGGCTCTCGCGCCG-1-0-0-0  Bladder1204               1963
# ...                               ...                ...
# TTGTGCAGCCACGTCA-1-1       Bladder371               1031
# TTGTGGCCCTGACAGT-1-1       Bladder371               3102
# TTGTGTTTCCCGAAAG-1-1       Bladder371               1288
# TTGTTAGCAAATTCGA-1-1       Bladder371               2112
# TTGTTCAGTGTGCTAC-1-1       Bladder371               3010
#
#                           log1p_n_genes_by_counts  total_counts  \
# AAACCGTTCGTCCAGG-1-0-0-0                 7.108244        1696.0
# AAACGAGACGGTTGAT-1-0-0-0                 8.088869        6578.0
# AAACTGCTGGCTCCAA-1-0-0-0                 8.127405        6858.0
# AAAGGCTACGGACCAT-1-0-0-0                 7.780303        4399.0
# AAAGGCTCTCGCGCCG-1-0-0-0                 7.582738        3184.0
# ...                                           ...           ...
# TTGTGCAGCCACGTCA-1-1                     6.939254        1596.0
# TTGTGGCCCTGACAGT-1-1                     8.040125        7971.0
# TTGTGTTTCCCGAAAG-1-1                     7.161622        2108.0
# TTGTTAGCAAATTCGA-1-1                     7.655864        4357.0
# TTGTTCAGTGTGCTAC-1-1                     8.010028        7805.0
#
#                           log1p_total_counts  pct_counts_in_top_50_genes  \
# AAACCGTTCGTCCAGG-1-0-0-0            7.436617                   18.396226
# AAACGAGACGGTTGAT-1-0-0-0            8.791638                   16.950441
# AAACTGCTGGCTCCAA-1-0-0-0            8.833317                   19.072616
# AAAGGCTACGGACCAT-1-0-0-0            8.389359                   19.686292
# AAAGGCTCTCGCGCCG-1-0-0-0            8.066208                   20.069095
# ...                                      ...                         ...
# TTGTGCAGCCACGTCA-1-1                7.375882                   26.190476
# TTGTGGCCCTGACAGT-1-1                8.983690                   22.682223
# TTGTGTTTCCCGAAAG-1-1                7.653969                   23.292220
# TTGTTAGCAAATTCGA-1-1                8.379768                   22.125316
# TTGTTCAGTGTGCTAC-1-1                8.962648                   22.152466
#
#                           pct_counts_in_top_100_genes  \
# AAACCGTTCGTCCAGG-1-0-0-0                    26.356132
# AAACGAGACGGTTGAT-1-0-0-0                    23.532989
# AAACTGCTGGCTCCAA-1-0-0-0                    25.590551
# AAAGGCTACGGACCAT-1-0-0-0                    27.301659
# AAAGGCTCTCGCGCCG-1-0-0-0                    27.386935
# ...                                               ...
# TTGTGCAGCCACGTCA-1-1                        34.774436
# TTGTGGCCCTGACAGT-1-1                        32.003513
# TTGTGTTTCCCGAAAG-1-1                        32.874763
# TTGTTAGCAAATTCGA-1-1                        31.237090
# TTGTTCAGTGTGCTAC-1-1                        31.800128
#
#                           pct_counts_in_top_200_genes  \
# AAACCGTTCGTCCAGG-1-0-0-0                    38.148585
# AAACGAGACGGTTGAT-1-0-0-0                    32.335056
# AAACTGCTGGCTCCAA-1-0-0-0                    33.712453
# AAAGGCTACGGACCAT-1-0-0-0                    36.758354
# AAAGGCTCTCGCGCCG-1-0-0-0                    36.777638
# ...                                               ...
# TTGTGCAGCCACGTCA-1-1                        47.305764
# TTGTGGCCCTGACAGT-1-1                        43.206624
# TTGTGTTTCCCGAAAG-1-1                        44.165085
# TTGTTAGCAAATTCGA-1-1                        42.299748
# TTGTTCAGTGTGCTAC-1-1                        42.588085
#
#                           pct_counts_in_top_500_genes  total_counts_mt  \
# AAACCGTTCGTCCAGG-1-0-0-0                    57.488208             48.0
# AAACGAGACGGTTGAT-1-0-0-0                    47.978109            113.0
# AAACTGCTGGCTCCAA-1-0-0-0                    48.235637            159.0
# AAAGGCTACGGACCAT-1-0-0-0                    52.716526            125.0
# AAAGGCTCTCGCGCCG-1-0-0-0                    54.051508             59.0
# ...                                               ...              ...
# TTGTGCAGCCACGTCA-1-1                        66.729323            129.0
# TTGTGGCCCTGACAGT-1-1                        58.650107            305.0
# TTGTGTTTCCCGAAAG-1-1                        62.618596            120.0
# TTGTTAGCAAATTCGA-1-1                        59.742942            245.0
# TTGTTCAGTGTGCTAC-1-1                        58.436899            211.0
#
#                           log1p_total_counts_mt  pct_counts_mt  n_counts
# AAACCGTTCGTCCAGG-1-0-0-0               3.891820       2.830189    1696.0
# AAACGAGACGGTTGAT-1-0-0-0               4.736198       1.717847    6578.0
# AAACTGCTGGCTCCAA-1-0-0-0               5.075174       2.318460    6858.0
# AAAGGCTACGGACCAT-1-0-0-0               4.836282       2.841555    4399.0
# AAAGGCTCTCGCGCCG-1-0-0-0               4.094345       1.853015    3184.0
# ...                                         ...            ...       ...
# TTGTGCAGCCACGTCA-1-1                   4.867535       8.082706    1596.0
# TTGTGGCCCTGACAGT-1-1                   5.723585       3.826370    7971.0
# TTGTGTTTCCCGAAAG-1-1                   4.795791       5.692600    2108.0
# TTGTTAGCAAATTCGA-1-1                   5.505332       5.623136    4357.0
# TTGTTCAGTGTGCTAC-1-1                   5.356586       2.703395    7805.0
#
# [4086 rows x 17 columns]

# %%
adata.var["mt"] = adata.var_names.str.startswith("MT-")
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt"], inplace=True)
#sc.pp.filter_cells(adata, min_counts=5000)
adata = adata[adata.obs.in_tissue != 0, :]
sc.pp.normalize_total(adata, inplace=True)
sc.pp.log1p(adata)
# Out:
# /Users/maruyamatooru/opt/anaconda3/envs/spatial/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:138: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
genes = ["in_tissue"]
for id in ["A1", "B1", "C1", "D1"]:
    sc.pl.spatial(adata[adata.obs.sampleID == id, :], 
                  img_key="lowres", 
                  color=genes,
                  alpha=1, 
                  library_id=id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-185e867d3997> in <module>
#       1 genes = ["in_tissue"]
#       2 for id in ["A1", "B1", "C1", "D1"]:
# ----> 3     sc.pl.spatial(adata[adata.obs.sampleID == id, :],
#       4                   img_key="lowres",
#       5                   color=genes,
#
# NameError: name 'sc' is not defined
